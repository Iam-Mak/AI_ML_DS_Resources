# %% [markdown]
# #  Python for Data Science Week - 1

# %% [markdown]
# ## Variable
# - An identifier containing a known information.
# - Information is referred to as value.
# - Variable name points to a memory address or a storage location and used to reference the stored value.

# %%
a = 11
b = a*10
print(a,b)
# Out:
# 11 110

# %%
a = 14
b = a*10
print(a,b)
# Out:
# 14 140

# %%
# Calculate Volume of Cylinder 
# dia is for diameter
dia = 5

# len is for length
len = 4

# vol is for volume
vol = 3.14*(dia**2)*len/4
print('Volume of cylinder is :' , vol)
# Out:
# Volume of cylinder is : 78.5

# %% [markdown]
# ### Basic libraries
# - **[NumPy](https://numpy.org/doc/1.22/index.html)** - Numerical Python
# - **[Pandas](https://pandas.pydata.org/docs/)** - Dataframe Python
# - **[Matplotlib](https://matplotlib.org/stable/users/index.html)** - Visualization
# - **[Sklearn](https://scikit-learn.org/stable/)** - Machine Learning

# %% [markdown]
# ## Naming variables
# - Values assigned to variables using an
# assignment operator‘=’.
# - Variable name should be short and
# descriptive .<br>
# ◦ Avoid using variable names that clash with
# inbuilt functions.
#
# - Designed to indicate the intent of its use to
# the end user.
# - Avoid one character variable names. <br>
# ◦ One character variable names are usually
# used in looping constructs, functions, etc.

# %%
# assigning values to multiple variables
Physics,Chemistry,Mathematics = 89,90,75
print('Physics :',Physics)
print('Chemistry :',Chemistry)
print('Mathematics :',Mathematics)
# Out:
# Physics : 89
# Chemistry : 90
# Mathematics : 75

# %% [markdown]
# ## Basic data types
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Identifying object data type
# Find data type of object using Syntax : `type(object)`

# %%
Employee_name ="Ram"
print(type(Employee_name))
# Out:
# <class 'str'>

# %%
Age = 55
print(type(Age))
# Out:
# <class 'int'>

# %%
Height = 150.6
print(type(Height))
# Out:
# <class 'float'>

# %% [markdown]
# ## Coercing object to new data type
# - Convert the data type of an object to anothe Syntex : `datatype(object)`
# - Changes can be stored in same variable or in different variable.

# %%
# convert height data type from `float` to `int`.
ht = int(Height)
print(type(ht))
# Out:
# <class 'int'>

# %%
Salary_tier = '1'
print(type(Salary_tier))
# Out:
# <class 'str'>

# %%
Salary_tier = int(Salary_tier)
print(type(Salary_tier))
# Out:
# <class 'int'>

# %% [markdown]
# ## Operators and operands
# - Operators are special symbols that help in carrying out an assignment operation of arithmatic or logical computation.
# - Value that the operator operates on is called operand.

# %% [markdown]
# ###  Arithmetic operators
# - Used to perform mathematical operations between two
# operands.
# - Create two variable a and b with values 10 and 5 respectively.
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Hierarchy of arithmetic operators
# ![image.png](attachment:image.png)

# %%
A = 7 - 2*(27/3**2) + 4
print(A)
# Out:
# 5.0

# %% [markdown]
# ### Assignment operators
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Relational or comparison operators
# - Tests numerical equalities and inequalities between two operands and returns a boolean value
# - All operators have same precedence
# - Create two variables x and y with values 5 and 7 respectively
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Logical operators
# - Used when operands are conditional statements and returns boolean value.
# - In python, logical operators are designed to work with scalars or boolean
# values.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bitwise operators
# - Used when operands are integers
# - Integers are treated as a string of binary digits.
# - Operates bit by bit
# - Can also operate on conditional statements which compare scalar
# values or arrays
# - Bitwise OR (|), AND(&)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Precedence of operators
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Week 1: Practice Assignment 1

# %% [markdown]
# **Q1** Which of the following is/are valid variable naming convention(s) in Python?
# - ageEmp = 45
# - AgeEmp = 45
# - age_emp = 45
# - AGE_EMP = 45
#
# `Ans : All`
#
# **Q2** Which of the following is not accepted as a representation of complex numbers in Python?
# - k = 2 + 3j
# - k = complex(2, 3)
# - k = 2 + 3l
# - k = 2 + 3J
#
# `Ans : k = 2 + 3l`
#
# **Q3** What is the output of the following expression, 7//2?
# - 1
# - 3
# - 7
# - 2
#
# `Ans : 3`
#
# **Q4** Which of the following functions returns a valid list of attributes of the object it is called upon?
# - print()
# - bin()
# - abs()
# - dir()
#
# `Ans : dir()`
#
# **Q5** An entity that can be different assigned different values is called__
# - Operator
# - Operand
# - Variable
# - Value
# `Ans : Variable`

# %% [markdown]
# ## Week 1: Assignment 1

# %% [markdown]
# **Q1** Which of the arithmetic operators given below cannot be used with ‘strings’ in Python?
# - ∗
# - −
# - +
# - All of the above
#
# `Ans : *`

# %%
print('A' +'A')
print('A_','A')

# Wrong
print('A'*'A')
# Out:
# AA
# A_ A
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-1eb0b50f1fcc> in <module>
#       1 print('A' +'A')
#       2 print('A_','A')
# ----> 3 print('A'*'A')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# **Q2** When the following statement is executed, what type of error is obtained? <br>
# `var@check = 10`
# - Type Error
# - Syntax Error
# - Value Error
# - None of the above
#
# `Ans : Syntax Error`

# %%
var@check = 10
# Out:
#   File "<ipython-input-105-f0b02fc15a28>", line 1
#     var@check = 10
#     ^
# SyntaxError: cannot assign to operator

# %% [markdown]
# **Q3** Two variables X and Y were assigned the following values initially. X = 3 and Y = 6. Which of the following statements will help swap the values between these two variables?
# - Y = X <br>
#      X = Y
# - X = Y
# - X = Y <br>
#      Y = X
# - X, Y = Y, X
#
# `Ans X, Y = Y, X`

# %%
X = 3
Y = 6
print(X,Y)

X, Y = Y, X
print(X,Y)
# Out:
# 3 6
# 6 3

# %% [markdown]
# **Q4** From the following set of statements, what will be the value of variable y in the final print statement? <br>
# `  y = 1**2**3**2
#    print("Variable y:",y)
# `
# - 8
# - 9
# - 1
# - Error
# - 16
#
# ` Ans : 1`

# %%
y = 1**2**3**2
print("Variable y:",y)
# Out:
# Variable y: 1

# %% [markdown]
# **Q5** Consider j = 5 and k = 11. We change the values from j = 7 and k remains constant.<br>
# What is print(j|k) before and after modification of value in variable j?
# - 3,15
# - 15,15
# - 11,15
# - 15,7
# - None of the above
#
# `Ans : 15,15`

# %%
j =5
k = 11
print(j|k)

j =7
k = 11
print(j|k)
# Out:
# 15
# 15

# %% [markdown]
# **Q6** What would be the output of the following statements? <br>
# `log_exp = not not True and False or not False
# print(log_exp)
# `
# - False
# - True
# - Not True
# - None of the above
#
# `Ans : True`

# %%
log_exp = not not True and False or not False
print(log_exp)
# Out:
# True

# %% [markdown]
# **Q7** What does k = 4%7 evaluate to and what is the type of variable k?
# - 4,int
# - 0.0,float
# - 0,int
# - 1,int
# - None of the above
#
# `Ans : 4,int`

# %%
print(4%7)
print(type(4%7))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# **Q8** j = 6 and g = 3.3. If normal division and floor division was done between j and k, what would be the type of the resultant variable?
# - int,int
# - float,float
# - float,int
# - int,float
# - None of the above
#
# `Ans : float,float`

# %%
j = 6
g = 3.3
print(j/g)
print(type(j/g))
print(j//g)
print(type(j//g))
# Out:
# 1.8181818181818183
# <class 'float'>
# 1.0
# <class 'float'>

# %% [markdown]
# **Q9** Consider two answers to a question; answer1 and answer2. What is the output of the following set of statements? <br>
# `
# answer1 = True
# answer2 = False
# print(answer1*answer2)
# `
# - True
# - False
# - 0
# - 1
#
# ` Ans : 0`

# %%
answer1 = True
answer2 = False
print(answer1*answer2)
# Out:
# 0

# %% [markdown]
# **Q10** Consider the list of instructions and resulting outputs given below. Pick the set that is incorrect.
#
# `
# 1 print("Good", end = "")
# print("Day")
# Output -> GoodDay
# `
# <br>
#
# `
# 2 word1 = "Trial"
# print("Word is %s"%word1)
# Output -> Trial
# `
# <br>
#
# `
# 3 num1 = 23
# print("Number:%f"%num1)
# Output -> 23.000000
# `
# <br>
#
# `
# 4 print("ready\nsteady\ngo")
# Output -> ready
#           steady
#           go
# `
#
#
#
# - 4
# - 2
# - 1,3,4
# - 3,4
# - All are correct
#
# `Ans :2`

# %%
print("Good", end = "")
print("Day")

word1 = "Trial"
print("Word is %s"%word1) # wrong

num1 = 23
print("Number:%f"%num1)

print("ready\nsteady\ngo")
# Out:
# GoodDay
# Word is Trial
# Number:23.000000
# ready
# steady
# go
