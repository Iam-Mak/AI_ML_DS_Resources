# %% [markdown]
# # Hypothesis Testing
#
# ### Ques 1
# ![image-6.png](attachment:image-6.png)
#
# ### Sol.  <br>
# **Give Values**
# ![image-7.png](attachment:image-7.png)
#
#
# ![image-8.png](attachment:image-8.png)

# %%
from scipy import stats

from scipy.stats import norm

# %%
# for p-value 

1-stats.norm.cdf(1.09)
# Out:
# 0.1378565720320355

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ## 1. p –Value Approach
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 2. Critical Value Approach
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## For 2 Tailed Test
#
# Compute the p-value using the following three steps:
# - Compute the value of the test statistic z.
# - If z is in the upper tail `(z > 0)`, find the area under the standard normal curve to the right of `z`.
# - If z is in the lower tail (`z < 0)`, find the area under the standard normal curve to the left of `z`.
# - Double the tail area obtained in step 2 to obtain the `p –value`.
#
# The rejection rule:
#
# Reject `H0` if the `p-value =< a`.
#
# Critical Value Approach to Two-Tailed Hypothesis Testing
# - The critical values will occur in both the lower and upper tails of the standard normal curve.
# - Use the standard normal probability distribution table to find za/2 (the z-value with an area of a/2
# in the upper tail of the distribution).
# - The rejection rule is:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ques 2
#
# ![image-3.png](attachment:image-3.png)
#
# ### Sol.
#
#
#
# **Give Values**
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# find p - value
p = 1-stats.norm.cdf(2.74)
p
# Out:
# 0.003071959218650444

# %%
# multiply by 2 , to get both side value

2*p
# Out:
# 0.006143918437300888

# %% [markdown]
# ## 1. p –Value Approach
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## 2. Critical Value Approach
#
# ![image-3.png](attachment:image-3.png)

# %%
# to find critical value


stats.norm.ppf(0.015)
# Out:
# -2.1700903775845606

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 3. Confidence Interval Approach
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Tests About a Population Mean: sigma Unknown
#
# #### Test Statistic
#
# ![image.png](attachment:image.png)
#
# ##  p –Value Approach
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

x = [10,12,20,21,22,24,18,15]
stats.ttest_1samp(x,15)
# Out:
# Ttest_1sampResult(statistic=1.5623450931857947, pvalue=0.1621787560592894)

# %% [markdown]
# ### Ques 3
# ![image.png](attachment:image.png)

# %%
ice_creame_no = [13,8,10,10,8,9,10,11,6,8,12,11,11,12,10,12,7,10,11,8]

stats.ttest_1samp(ice_creame_no,10)
# Out:
# Ttest_1sampResult(statistic=-0.35843385854878496, pvalue=0.7239703579964252)

# %%
pvalue = 0.7239703579964252

pval_divby_2 = pvalue/2
pval_divby_2
# Out:
# 0.3619851789982126

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stats.t.cdf(-0.384,19)
# Out:
# 0.35262102566795583

# %%
stats.t.ppf(0.05,19)
# Out:
# -1.7291328115213678

# %% [markdown]
# ## Hypothesis Testing – proportion
#
# Null and Alternative Hypotheses: **Population Proportion**
#
#
# - The equality part of the hypotheses always appears in the null hypothesis.
# - In general, a hypothesis test about the value of a population proportion `p` must take one of the following three forms (where `p0` is the hypothesized value of the population proportion).
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png)

# %%
from statsmodels.stats.proportion import proportions_ztest

# %% [markdown]
# ## 1. p –Value Approach
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-5.png](attachment:image-5.png)

# %%
count = 67

sample_size = 120

p = 0.5

proportions_ztest(count,sample_size,p)
# Out:
# (1.286806739751111, 0.1981616572238455)

# %% [markdown]
# ## 2. Critical Value Approach
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Errors in Hypothesis Testing
#
# ### Type I Error
# The true mean burning rate of the propellant could be equal to 50 centimeters per second
#
# - However randomly selected propellant specimens that are tested, we could observe a value of test statistics $"\bar{x}"$ that falls into the **critical region(rejection region)**.
#
# - We would then reject the null hypothesis Ho in favor of the alternate `H1`, in fact, `Ho` is really true
#
# - This type of wrong conclusion is called a `type I error`
#
# ![image.png](attachment:image.png)
#
# ### Type II Error
#
# - Now suppose the true mean burning rate is different from 50 centimeters per second, yet the sample mean $"\bar{x}"$ falls in the **acceptance region**
# - In this case we would fail to reject Ho when it is false
#
# - This type of wrong conclusion is called a `type II error`
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Example
# ![image.png](attachment:image.png)
#
# ### Value of the null hypothesis
# The value of the null hypothesis can be obtained by
#
# - Past experience or knowledge of the process, or even from the previous tests or experiments
#
# - From some theory or model regarding the process under study
#
# - From external consideration, such as design or engineering specifications, or from contractual obligations

# %% [markdown]
# ### Sol.
#
# ### Type I error
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
def z_value(x,mu,SEM):
    z = (x-mu)/SEM
    if (z<0):
        alpha = stats.norm.cdf(z)
    else:
        alpha = 1 - stats.norm.cdf(z)
    print(alpha)

# %%
# calculate alpha for different values of x,mu and SEM

x = 48.5
mu = 50
SEM = 0.79

z_value(x,mu,SEM)
# Out:
# 0.02879971774715278

# %% [markdown]
# - Type I error = 0.057434
# - This implies that 5.7 % of all random samples would lead to rejection of the hypothesis Ho: μ=50 centimeters per second.
# - We can reduce the type I error by widening the acceptance region. If we make critical value 48 and 52, the value of alpha is 0.0114 ( adding 0.0057 and 0.0057).
# - Change sample size to 16 then alpha is 0.0164.

# %%
z_value(48,mu,SEM)
# Out:
# 0.005676434117424844

# %%
z_value(52,mu,SEM)
# Out:
# 0.0056764341174248

# %% [markdown]
# ### TYPE II ERROR
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
beta = stats.norm.cdf((51.5-52)/0.79)
beta
# Out:
# 0.26339575390741593

# %%
beta = stats.norm.cdf((51.5-50.5)/0.79)
beta
# Out:
# 0.8972117321157791

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### Type I & II Errors Have an Inverse Relationship
# - If we reduce the probability of one error, the other one increases so that everything else is unchanged.
#
# ### Factors Affecting Type II Error
# - True value of population parameter
#     - $\beta$ Increases when the difference between hypothesized parameter and its true value decrease <br>
# - Significance level $\alpha$
#      - Increases when $\beta$ decreases <br>
# - Population standard deviation
#     - Increases when $\beta$ increases<br>
# - Sample size
#   - $\beta$ Increases when n decreases

# %% [markdown]
# ### Ques
#
# Ho: μ = 8.3
# H1: μ < 8.3
#
# Determine the probability of Type II error if `μ = 7.4` at `5%` significance level. `σ = 3.1` and `n = 60`.

# %%
# Sol

def type_2(mu1,mu2,sigma,n,alpha):
    z = stats.norm.ppf(alpha)
    x_bar = (mu1)+(z*sigma/np.sqrt(n))
    z2 = (x_bar-mu2)/(sigma/np.sqrt(n))
    if(mu1 > mu2):
        beta = 1- stats.norm.cdf(z2)
    else:
        bets = stats.norm.cdf(z2)
    
    print(beta)

# %%
type_2(8.3,7.4,3.1,60,0.05)
# Out:
# 0.27292999450730004

# %% [markdown]
# An error will be made when `Z ≥ -1.645`, for that will fail to reject Ho.<br>
# `β = 0.2729`
#
# ### Power of the Test
#
# - The probability of correctly rejecting H0 when it is false is called the power of the test.
# -  For any particular value of m, the power is 1 – $\beta$.
# - We can show graphically the power associated with each value of $\mu$ ; such a graph is called a `power curve`.
#
# ![image.png](attachment:image.png)
